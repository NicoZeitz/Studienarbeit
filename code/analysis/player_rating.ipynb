# %%
# Player { rating: 1958.7953973628526, d: 69.27896875467901, v: 0.06092743352404568, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: score, eval: score)" }, interval: [1823.0086186036817, 1958.7953973628526, 2094.5821761220236]
# Player { rating: 1946.5299316791434, d: 62.91165122705936, v: 0.05988223512530038, name: "MCTSPlayer(tree: reuse, root: 1, leaf: 1, policy: uct, eval: win)" }, interval: [1823.223095274107, 1946.5299316791434, 2069.8367680841798]
# Player { rating: 1917.7896324785584, d: 70.43024522643256, v: 0.06064632989063215, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: uct, eval: score)" }, interval: [1779.7463518347506, 1917.7896324785584, 2055.8329131223663]
# Player { rating: 1914.0942685913894, d: 65.84739897633656, v: 0.061479186730437986, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: uct, eval: win)" }, interval: [1785.0333665977698, 1914.0942685913894, 2043.155170585009]
# Player { rating: 1902.9025810316168, d: 69.2519927860928, v: 0.06005568157543335, name: "MCTSPlayer(tree: reuse, root: 8, leaf: 1, policy: uct, eval: win)" }, interval: [1767.1686751708748, 1902.9025810316168, 2038.6364868923588]
# Player { rating: 1837.9255862330333, d: 70.15489522751555, v: 0.06122261184437128, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: partial-score, eval: win)" }, interval: [1700.4219915871029, 1837.9255862330333, 1975.4291808789637]
# Player { rating: 1827.856453322947, d: 66.90991719313128, v: 0.06020368688662927, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: partial-score, eval: score)" }, interval: [1696.7130156244095, 1827.856453322947, 1958.9998910214842]
# Player { rating: 1741.5956972718302, d: 66.66685567670702, v: 0.061219440113111076, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: score, eval: win)" }, interval: [1610.9286601454844, 1741.5956972718302, 1872.262734398176]
# Player { rating: 1687.6126046119198, d: 66.53853956183298, v: 0.06008406583639119, name: "MCTSPlayer(tree: reuse, root: 1, leaf: 8, policy: uct, eval: win)" }, interval: [1557.1970670707271, 1687.6126046119198, 1818.0281421531124]
# Player { rating: 1534.847876558347, d: 73.5759699610823, v: 0.06146787186597002, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: partial-score, eval: static)" }, interval: [1390.6389754346258, 1534.847876558347, 1679.0567776820683]
# Player { rating: 1413.2560782282826, d: 80.56872256977324, v: 0.06266991270861465, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: score, eval: static)" }, interval: [1255.341381991527, 1413.2560782282826, 1571.1707744650382]
# Player { rating: 1355.0625948948727, d: 71.58173542531333, v: 0.059834590669843334, name: "PVSPlayer(time: 10s, ord: table, eval: static, fail: Hard, asp: true, lmr: true, lmp: true, ext: true, tt: Symmetry(Size: MiB(10), Strategy: Hard), smp: Yes(Parallelism: 8))" }, interval: [1214.7623934612586, 1355.0625948948727, 1495.3627963284869]
# Player { rating: 1352.727627468434, d: 62.50055531163871, v: 0.0600957762301725, name: "GreedyPlayer(eval: score)" }, interval: [1230.2265390576222, 1352.727627468434, 1475.228715879246]
# Player { rating: 1302.0907608597843, d: 60.72141201283344, v: 0.060029872078965846, name: "PVSPlayer(time: 10s, ord: table, eval: static, fail: Hard, asp: false, lmr: true, lmp: true, ext: true, tt: Symmetry(Size: MiB(10), Strategy: Hard), smp: No)" }, interval: [1183.0767933146308, 1302.0907608597843, 1421.1047284049378]
# Player { rating: 1279.2825220656039, d: 60.539186113060445, v: 0.060019734844873066, name: "PVSPlayer(time: 10s, ord: table, eval: static, fail: Hard, asp: true, lmr: true, lmp: true, ext: false, tt: Symmetry(Size: MiB(10), Strategy: Hard), smp: No)" }, interval: [1160.6257172840053, 1279.2825220656039, 1397.9393268472024]
# Player { rating: 1267.4661093649916, d: 60.538463312146206, v: 0.0600298304570154, name: "PVSPlayer(time: 10s, ord: table, eval: static, fail: Hard, asp: true, lmr: false, lmp: false, ext: true, tt: Symmetry(Size: MiB(10), Strategy: Hard), smp: No)" }, interval: [1148.810721273185, 1267.4661093649916, 1386.1214974567981]
# Player { rating: 1256.1419373297676, d: 87.90923716907943, v: 0.05907349809093564, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: uct, eval: static)" }, interval: [1083.839832478372, 1256.1419373297676, 1428.4440421811632]
# Player { rating: 1253.3762262393104, d: 64.63646229627835, v: 0.060096641886772925, name: "GreedyPlayer(eval: static)" }, interval: [1126.688760138605, 1253.3762262393104, 1380.063692340016]
# Player { rating: 1221.2534277283753, d: 62.912420114504485, v: 0.05986959975310248, name: "PVSPlayer(time: 10s, ord: table, eval: static, fail: Hard, asp: true, lmr: true, lmp: true, ext: true, tt: Symmetry(Size: MiB(10), Strategy: Hard), smp: No)" }, interval: [1097.9450843039465, 1221.2534277283753, 1344.561771152804]
# Player { rating: 1200.025284893405, d: 61.55552721406706, v: 0.060009106498574036, name: "PVSPlayer(time: 10s, ord: table, eval: static, fail: Soft, asp: true, lmr: true, lmp: true, ext: true, tt: Symmetry(Size: MiB(10), Strategy: Soft), smp: No)" }, interval: [1079.3764515538335, 1200.025284893405, 1320.6741182329763]
# Player { rating: 1037.822956902974, d: 62.949982539857665, v: 0.060009907770556946, name: "AlphaZeroPlayer(policy: puct, batch_size: 20, parallelization: 16)" }, interval: [914.440991124853, 1037.822956902974, 1161.204922681095]
# Player { rating: 952.4631875546679, d: 65.61250325175868, v: 0.05996656830391919, name: "RandomPlayer" }, interval: [823.8626811812209, 952.4631875546679, 1081.0636939281148]

# %%
# Player { rating: 1958.7953973628526, d: 69.27896875467901, v: 0.06092743352404568, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: score, eval: score)" }, interval: [1823.0086186036817, 1958.7953973628526, 2094.5821761220236]
# Player { rating: 1946.5299316791434, d: 62.91165122705936, v: 0.05988223512530038, name: "MCTSPlayer(tree: reuse, root: 1, leaf: 1, policy: uct, eval: win)" }, interval: [1823.223095274107, 1946.5299316791434, 2069.8367680841798]
# Player { rating: 1917.7896324785584, d: 70.43024522643256, v: 0.06064632989063215, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: uct, eval: score)" }, interval: [1779.7463518347506, 1917.7896324785584, 2055.8329131223663]
# Player { rating: 1914.0942685913894, d: 65.84739897633656, v: 0.061479186730437986, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: uct, eval: win)" }, interval: [1785.0333665977698, 1914.0942685913894, 2043.155170585009]

# Player { rating: 1902.9025810316168, d: 69.2519927860928, v: 0.06005568157543335, name: "MCTSPlayer(tree: reuse, root: 8, leaf: 1, policy: uct, eval: win)" }, interval: [1767.1686751708748, 1902.9025810316168, 2038.6364868923588]

# Player { rating: 1837.9255862330333, d: 70.15489522751555, v: 0.06122261184437128, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: partial-score, eval: win)" }, interval: [1700.4219915871029, 1837.9255862330333, 1975.4291808789637]
# Player { rating: 1827.856453322947, d: 66.90991719313128, v: 0.06020368688662927, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: partial-score, eval: score)" }, interval: [1696.7130156244095, 1827.856453322947, 1958.9998910214842]
# Player { rating: 1741.5956972718302, d: 66.66685567670702, v: 0.061219440113111076, name: "MCTSPlayer(tree: new, root: 1, leaf: 1, policy: score, eval: win)" }, interval: [1610.9286601454844, 1741.5956972718302, 1872.262734398176]

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
players = [
    {
        'name': 'Random',
        'interval': [823.8626811812209, 952.4631875546679, 1081.0636939281148]
    },
    {
        'name': "Greedy\n(eval: static)",
        'interval': [1126.688760138605, 1253.3762262393104, 1380.063692340016]
    },
    {
        'name': "Greedy\n(eval: score)",
        'interval': [1230.2265390576222, 1352.727627468434, 1475.228715879246]
    },
    {
        'name': 'PVS\n(1 Thread)',
        'interval': [1183.0767933146308, 1302.0907608597843, 1421.1047284049378]
    },
    {
        'name': 'PVS\n(8 Threads)',
        'interval': [1214.7623934612586, 1355.0625948948727, 1495.3627963284869]
    },
    {
        'name': 'MCTS\n(eval: static)',
        'interval': [1083.839832478372, 1256.1419373297676, 1428.4440421811632]
    },
    {
        'name': 'MCTS\n(eval: win)',
        'interval': [1785.0333665977698, 1914.0942685913894, 2043.155170585009]
    },
    {
        'name': 'MCTS\n(eval: score)',
        'interval': [1779.7463518347506, 1917.7896324785584, 2055.8329131223663]
    },
    {
        'name': 'MCTS\n(leaf: 8)',
        'interval': [1557.1970670707271, 1687.6126046119198, 1818.0281421531124]
    },
    {
        'name': 'MCTS\n(root: 8)',
        'interval': [1823.0086186036817, 1958.7953973628526, 2094.5821761220236]
        # [1767.1686751708748, 1902.9025810316168, 2038.6364868923588]
    },
    {
        'name': 'AlphaZero',
        'interval': [914.440991124853, 1037.822956902974, 1161.204922681095]
    },
]

# %%
# split data
point_estimates = [player['interval'][1] for player in players]
lower_bounds = [player['interval'][0] for player in players]
upper_bounds = [player['interval'][2] for player in players]

# parameters for mathplotlib export
plt.rcParams['svg.fonttype'] = 'path'
plt.rcParams['pdf.use14corefonts'] = True
plt.rcParams["figure.autolayout"] = True
plt.rcParams['axes.unicode_minus'] = False

x = range(len(players))

# create plot
fig, ax = plt.subplots(figsize=(10, 6))

# set x and y limits and ticks, draw horizontal grid lines
ax.set_ylim(500, 2550)
ax.set_xlim(-0.35, len(players) - 0.35)
ax.set_xticks(x)
ax.set_xticklabels([f"{player['interval'][1]:.2f}\n{player['name']}".replace('.',',') for player in players])
yticks = ax.get_yticks()
for ytick in yticks[1:]:
    ax.hlines(ytick, xmin=-0.35, xmax=len(players)-1+0.35, linestyle='--', color='gray', alpha=0.5)

# Change Design, Remove Borders add arrow to y-axis
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel('Spieler', labelpad=10)
plt.ylabel('Glicko2 Rating')
ax.annotate('', xy=(0, 0.995), xytext=(0, 1.05), arrowprops=dict(arrowstyle='<|-', color='black'), xycoords='axes fraction')

# Plot Confidence Intervals and Points
ax.errorbar(x, point_estimates, yerr=[[point_estimates[i] - lower_bounds[i] for i in range(len(players))],
                                       [upper_bounds[i] - point_estimates[i] for i in range(len(players))]],
             fmt='o', ecolor='skyblue', color="black", capsize=5, label='Konfidenzintervall')


# Create Legend
legend_confidence_interval = plt.Line2D([0], [0], color='skyblue', marker='o', markersize=8, linestyle='None', label='Confidence Interval')
legend_point_estimate = plt.Line2D([0], [0], color='black', marker='o', markersize=8, linestyle='None', label='Point Estimate')
ax.legend([legend_confidence_interval, legend_point_estimate], ['95% Konfidenzintervall', 'Punktschätzer'])

# fig.tight_layout()

# Export
results_dir = f'../../T3_3101/res/pictures/plots'
if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

plt.savefig(f'{results_dir}/player-ratings.svg', bbox_inches = 'tight', dpi=1200)
plt.savefig(f'{results_dir}/player-ratings.pdf', bbox_inches = 'tight', dpi=1200)
plt.savefig(f'{results_dir}/player-ratings.png', bbox_inches = 'tight', dpi=1200)

# fig.show()
