     0.154903329244,  0.125028841276,  0.110261631702,  0.077651002500,  0.100022078879,  0.098044662501,  0.012280558156,  0.093146199006,  0.028042753610, # 72 - 80
]).reshape((9,9))
# Special Patch Endgame
special_patch_end = np.array([
     0.071094079691,  0.051853393331,  0.024562754255,  0.046840564940,  0.047897965196,  0.052571426359,  0.045672832074,  0.018775736785,  0.087169378509, #  0 -  8
     0.064988599810,  0.040771332177, -0.002465200199,  0.009034178447, -0.020790348441,  0.020399805528,  0.084501994510,  0.015766067273,  0.023936203512, #  9 - 17
     0.045993280509,  0.013765393356,  0.017056733137,  0.048046392320,  0.055175507835, -0.007416158077,  0.006271914897,  0.027495270425, -0.002781031986, # 18 - 26
     0.052391956534,  0.063323781630,  0.057275685282,  0.034758516297,  0.019131664670,  0.015602631456,  0.013078372130,  0.040191571808,  0.038601196074, # 27 - 35
     0.058104990921,  0.021868257167,  0.057990033261,  0.058127136998,  0.013249230791,  0.029715937635,  0.030261418242, -0.005231758524,  0.033135344134, # 36 - 44
     0.076410368339,  0.059261648691,  0.074492454907,  0.014811436381,  0.013442205485,  0.039795095520, -0.002271623610, -0.003679739566,  0.066219203797, # 45 - 53
     0.007542806269,  0.001994855910,  0.005508389514,  0.043591214574,  0.005606569482,  0.019894117848,  0.006596946485,  0.026388718811,  0.069018668764, # 54 - 62
    -0.000322695035, -0.002152656993,  0.030151678953,  0.053403779430, -0.007774519900,  0.050973741963,  0.056153101919,  0.058629578294,  0.062496606886, # 63 - 71
     0.106154681446,  0.027253493921,  0.025342577981,  0.044026787744,  0.053397783123,  0.083176863710,  0.027044681563,  0.059474416967,  0.083085096021, # 72 - 80
]).reshape((9,9))

# %%
plt.rcParams['svg.fonttype'] = 'path'
plt.rcParams['pdf.use14corefonts'] = True
plt.rcParams["figure.autolayout"] = True
plt.rcParams['axes.unicode_minus'] = False

# %%
total_min = min(
    np.min(patch_17_op),
    np.min(patch_17_end),
    np.min(patch_20_op),
    np.min(patch_20_end),
    np.min(patch_21_op),
    np.min(patch_21_end),
    np.min(patch_22_op),
    np.min(patch_22_end),
    np.min(patch_23_op),
    np.min(patch_23_end),
    np.min(patch_24_op),
    np.min(patch_24_end),
    np.min(special_patch_op),
    np.min(special_patch_end),
)
total_max = max(
    np.max(patch_17_op),
    np.max(patch_17_end),
    np.max(patch_20_op),
    np.max(patch_20_end),
    np.max(patch_21_op),
    np.max(patch_21_end),
    np.max(patch_22_op),
    np.max(patch_22_end),
    np.max(patch_23_op),
    np.max(patch_23_end),
    np.max(patch_24_op),
    np.max(patch_24_end),
    np.max(special_patch_op),
    np.max(special_patch_end),
)

print(f"Total - min: {total_min}, max: {total_max}")

def create_heatmap(patch_id, opening, endgame):
    opening = np.array(opening)
    endgame = np.array(endgame)

    min_value = np.min(np.concatenate((opening, endgame), axis=1))
    avg_value = np.average(np.concatenate((opening, endgame), axis=1))
    max_value = np.max(np.concatenate((opening, endgame), axis=1))

    op_min_value = np.min(opening)
    op_avg_value = np.average(opening)
    op_max_value = np.max(opening)

    end_min_value = np.min(endgame)
    end_avg_value = np.average(endgame)
    end_max_value = np.max(endgame)

    print(f"Patch {patch_id}       - min: {min_value}, avg: {avg_value}, max: {max_value}")
    print(f"Patch {patch_id} (OP)  - min: {op_min_value}, avg: {op_avg_value}, max: {op_max_value}")
    print(f"Patch {patch_id} (END) - min: {end_min_value}, avg: {end_avg_value}, max: {end_max_value}")

    min_value = math.floor(min_value * 10) / 10
    max_value = math.ceil(max_value * 10) / 10

    fig, ax = plt.subplots(ncols=3, gridspec_kw=dict(width_ratios=[0.9,0.9,0.05]))

    labels = [1,2,3,4,5,6,7,8,9]
    # crest, rocket, mako, magma, viridis, rocket_r, flare
    # palette = sns.color_palette("RdYlGn_r", 5)
    # palette = sns.color_palette("RdYlGn", as_cmap=True)

    palette = None # "flare"
    g = sns.heatmap(
        opening,
        annot=True,
        fmt=".2f",
        cmap=palette,
        xticklabels=labels,
        yticklabels=labels,
        vmax=max_value,
        vmin=min_value,
        cbar=False,
        ax=ax[0],
    )
    g.set_yticklabels(g.get_yticklabels(), rotation=0)

    sns.heatmap(
        endgame,
        annot=True,
        fmt=".2f",
        cmap=palette,
        xticklabels=labels,
        yticklabels=["","","","","","","","",""],
        vmax=max_value,
        vmin=min_value,
        cbar=False,
        ax=ax[1],
    )
    ax[1].tick_params(left=False)

    fig.colorbar(ax[1].collections[0], cax=ax[2])

    (width, height) = fig.get_size_inches()
    fig.set_size_inches(width * 1.5, width * 1.5 / (2.1/1))

    fig.tight_layout()

    results_dir = f'../../T3_3101/res/pictures/plots'
    if not os.path.isdir(results_dir):
        os.makedirs(results_dir)

    plt.savefig(f'{results_dir}/{str(patch_id).rjust(2, "0")}-action-ordering.svg', bbox_inches = 'tight', dpi=1200)
    plt.savefig(f'{results_dir}/{str(patch_id).rjust(2, "0")}-action-ordering.pdf', bbox_inches = 'tight', dpi=1200)
    plt.savefig(f'{results_dir}/{str(patch_id).rjust(2, "0")}-action-ordering.png', bbox_inches = 'tight', dpi=1200)
    # plt.clf()


create_heatmap(17, patch_17_op, patch_17_end)
create_heatmap(20, patch_20_op, patch_20_end)
create_heatmap(21, patch_21_op, patch_21_end)
create_heatmap(22, patch_22_op, patch_22_end)
create_heatmap(23, patch_23_op, patch_23_end)
create_heatmap(24, patch_24_op, patch_24_end)
create_heatmap("special", special_patch_op, special_patch_end)
# Out:
# Total - min: -0.735216537033, max: 0.439645979172
# Patch 17       - min: -0.12291868217999999, avg: 0.06966822625598766, max: 0.384619982915
# Patch 17 (OP)  - min: 0.0, avg: 0.15039540595950618, max: 0.384619982915
# Patch 17 (END) - min: -0.12291868217999999, avg: -0.011058953447530865, max: 0.133519899691
# Patch 20       - min: -0.29533218059300004, avg: 0.07609763186057407, max: 0.42196804540000005
# Patch 20 (OP)  - min: -0.012691899046, avg: 0.13166299483633334, max: 0.42196804540000005
# Patch 20 (END) - min: -0.29533218059300004, avg: 0.020532268884814818, max: 0.37512697149700003
# Patch 21       - min: -0.735216537033, avg: -0.23979731276342595, max: 0.24356800835599998
# Patch 21 (OP)  - min: -0.735216537033, avg: -0.3806588530870741, max: -0.08030768171300001
# Patch 21 (END) - min: -0.516873951622, avg: -0.09893577243977779, max: 0.24356800835599998
# Patch 22       - min: -0.6371465421829999, avg: -0.15321197141373458, max: 0.439645979172
# ...
